# %%
# !pip install shexviz
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Production Shape
# * OBJECTID
# * Date of planting
# * Date of harvest
# * SeedingRatePerAcre
# * PercentBallOpened

# %%
from shexviz import shex2dot
f = open("cotton/productionShape.shex", "r")
shex = f.read()

shex2dot.shex2dot(shex, "test")
# Out:
#  dct: <http://purl.org/dc/terms/>
#  xsd: <http://www.w3.org/2001/XMLSchema#>
#  rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#  qudt: <http://qudt.org/schema/qudt/>
#  nalt: <https://lod.nal.usda.gov/nalt/>
#  unit: <http://qudt.org/vocab/unit/>
# line 8:9 extraneous input '@productionShape' expecting {<EOF>, KW_ABSTRACT, KW_BASE, KW_IMPORT, KW_PREFIX, KW_START, IRIREF, PNAME_NS, PNAME_LN, BLANK_NODE_LABEL}
# line 8:9 extraneous input '@productionShape' expecting {<EOF>, KW_ABSTRACT, KW_BASE, KW_IMPORT, KW_PREFIX, KW_START, IRIREF, PNAME_NS, PNAME_LN, BLANK_NODE_LABEL}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       2 f = open("cotton/productionShape.shex", "r")
#       3 shex = f.read()
# ----> 5 shex2dot.shex2dot(shex, "test")
#
# ...

# %%
OBJECTID
Date of planting
Date of harvest
ValuePerac
SeedingRatePerAcre
PercentBallOpened
