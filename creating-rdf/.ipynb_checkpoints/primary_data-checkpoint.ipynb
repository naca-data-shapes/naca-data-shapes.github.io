# %% [markdown]
# # Example (synthetic) data sets
# For the purpose of this effort to create a common data shape on Glioblastoma, two synthetic data sets were provided. Synthetic datasets contain fabricated data that is represtable of actual data on the topic.
#
# In this chapter we will inspect the provided datasets and prepare them to by converted into linked data. As described earlier, linked data is data that follows a linked-data format consisting of triples where the individual parts consists of either values or identifiers (IRIs) pointing to concept definitions.
#
# The proces of converting data to linked data is rather straightforwards and can be summed up as follows:
# 1. Inspect the data
# 2. Clean the data headers
# 3. Align the data with common controlled vocabularies or ontologies
# 4. Design linked-data shapes using the IRIs from the controlled vocabularies and ontologies
# 5. Transform the data into RDF
#
# In this chapter we will focus on the first two steps.

# %% [markdown]
# ## Dataset 1 on Glioblastoma
# The first dataset is a provided excel file (Sample clinical data_July 2022.xlsx) ## TODO add a link.
# It contains synthetic clinical data on patients with glioblastoma.

# %%
import pandas as pd
gdb1 = pd.read_excel("data/Sample clinical data_July 2022.xlsx")
gdb1
# Out:
#    ID Lab site ID clinical site        DOB  Age  Gender Pathology  \
# 0       Ge 829              DAG 1953-05-16    62      F       GBM
# 1       Ge 835              EAG 1964-06-18    50      M       GBM
# 2       Ge 849              FAG 1957-12-15    57      F       GBM
# 3       Ge 852              GAG 1960-03-22    55      M       GBM
# 4       Ge 882              IAG 1948-05-06    67      M       GBM
# 5      Ge 893*              KAG 1958-07-12    56      M       GBM
# 6       Ge 901              LAG 1991-06-09    23      F      AIII
# 7       Ge 904              MAG 1949-10-13    65      M       GBM
# 8       Ge 939              PAG 1972-04-10    43      F      AIII
# 9      Ge 941*              OAG 1954-01-07    61      M       GBM
# 10      Ge 950              QAG 1947-03-22    68      M       GBM
# 11     Ge 963*              RAG 1941-06-14    73      M      AIII
# 12      Ge 970              UAG 1971-05-01    44      M       GBM
# 13      Ge 977              VAG 1947-06-28    68      F       GBM
# 14     Ge 989*              WAG 1974-11-10    41      M       GBM
# 15      Ge 993              XAG 1951-12-07    63      M       GBM
# 16     Ge 1006              YAG 1955-11-05    60      M       GBM
# 17     Ge 1007              ZAG 1942-05-15    73      M       GBM
# 18     Ge 1018              ABG 1975-07-11    41      M       GBM
#
#                 Localization  IDH1/2 status MGMT status  ECOG  ...  \
# 0                  parietal R            wt      UnMeth     1  ...
# 1                  temporal D            wt      UnMeth     0  ...
# 2                   frontal R            wt      UnMeth     0  ...
# 3            fronto insular L            wt      UnMeth     0  ...
# 4            fronto insular R            wt      UnMeth     0  ...
# 5                  temporal R            wt        Meth     0  ...
# 6   fronto temporal insular R           mut      UnMeth     0  ...
# 7         parieto occipital L            wt        Meth     0  ...
# 8                  temporal R            wt      UnMeth     1  ...
# 9                   frontal L           mut        Meth     0  ...
# 10                 parietal L            wt      UnMeth     1  ...
# 11                  frontal L            wt      UnMeth     1  ...
# 12        pareito occipital R            wt      UnMeth     0  ...
# 13                 temporal L            wt        Meth     1  ...
# 14                temporal L             wt      UnMeth     0  ...
# 15       frontal L precentral            wt      UnMeth     1  ...
# 16           frontotemporal L            wt      UnMeth     0  ...
# 17                  frontal L            wt      UnMeth     1  ...
# 18         parieto temporal R            wt      UnMeth     0  ...
#
#    doses bevacizumab  Best response  pseudo-progression (1=yes 0=no) œdema  \
# 0                 12             PD                                0     1
# 1                  0             PD                                1     1
# 2                  9             PD                                1     0
# 3                 16             SD                                0     1
# 4                  4             PD                                0     1
# 5                  0             SD                                0     0
# 6                 29             SD                                1     0
# 7                  6             PR                                1     1
# 8                 42             PD                                1     1
# 9                  0             CR                                1     0
# 10                 8             PD                                0     1
# 11                 0             SD                                0     0
# 12                 8             PD                                0     1
# 13                 0             SD                                1     0
# 14                23             PD                                0     0
# 15                 7             PR                                1     0
# 16                14             PD                                0     1
# 17                14             PD                                0     0
# 18                15             PD                                0     1
#
#     PP or œdema  progression (1=yes 0=no)  date of progression months PFS  \
# 0             1                         1           2013-11-11          3
# 1             1                         1           2014-01-21          6
# 2             1                         1           2014-09-02         11
# 3             1                         1           2014-10-01         11
# 4             1                         1           2014-12-22         18
# 5             0                         1           2015-02-04         26
# 6             1                         1           2016-07-18         17
# 7             1                         1           2016-12-12         29
# 8             1                         1           2015-06-12          6
# 9             1                         0                  NaT         38
# 10            1                         1           2015-09-25          7
# 11            0                         1           2017-03-07         19
# 12            1                         1           2016-01-13          6
# 13            1                         1           2017-03-03         20
# 14            0                         1           2015-11-10          5
# 15            1                         1           2016-06-14         12
# 16            1                         1           2016-07-29         10
# 17            0                         1           2016-06-22          7
# 18            1                         1           2016-11-10         10
#
#     deceased (1=yes 0=no)  months OS
# 0                       1         19
# 1                       1         10
# 2                       1         18
# 3                       1         21
# 4                       1         24
# 5                       0         44
# 6                       1         37
# 7                       1         35
# 8                       1         32
# 9                       0         38
# 10                      1         11
# 11                      0         33
# 12                      1         13
# 13                      1         29
# 14                      0         30
# 15                      1         18
# 16                      1         18
# 17                      1         15
# 18                      1         18
#
# [19 rows x 26 columns]

# %%
gdb1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 26 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   ID Lab site                               19 non-null     object
#  1   ID clinical site                          19 non-null     object
#  2   DOB                                       19 non-null     datetime64[ns]
#  3   Age                                       19 non-null     int64
#  4   Gender                                    19 non-null     object
#  5   Pathology                                 19 non-null     object
#  6   Localization                              19 non-null     object
#  7   IDH1/2 status                             19 non-null     object
#  8   MGMT status                               19 non-null     object
#  9   ECOG                                      19 non-null     int64
#  10  Nature of initial resection               19 non-null     object
#  11  lymphocyte counts at V1 in G/L            19 non-null     float64
#  12  cummulative dose preV1 steroid use in mg  19 non-null     int64
#  13  steroid use after V1                      19 non-null     object
#  14  cummulative steroid dose in mg            19 non-null     float64
#  15   Cycles adj TMZ                           19 non-null     int64
#  16  doses bevacizumab                         19 non-null     int64
#  17  Best response                             19 non-null     object
#  18  pseudo-progression (1=yes 0=no)           19 non-null     int64
#  19  œdema                                     19 non-null     int64
#  20  PP or œdema                               19 non-null     int64
#  21  progression (1=yes 0=no)                  19 non-null     int64
#  22  date of progression                       18 non-null     datetime64[ns]
#  23  months PFS                                19 non-null     int64
#  24  deceased (1=yes 0=no)                     19 non-null     int64
#  25  months OS                                 19 non-null     int64
# dtypes: datetime64[ns](2), float64(2), int64(12), object(10)
# memory usage: 4.0+ KB

# %% [markdown]
# This dataset contains 26 fields of various datatypes. In one of the next steps this field names will be alligned with various controlled vocabularies and ontologies. For this to be succesful the fieldnames need to be as expressive as it can be.

# %%
def show_difference(row):
    highlight = 'background-color: yellow;'
    default = ''
    if row['original_field'] != row['prepared_field']:
        return [default, highlight]
    else:
        return [default, default]
    
def strip_check(row):
    if row['original_field'] != row['prepared_field']:
        row["change"] = "remove trailing spaces"
        
def abbreviations(row):
    if row['original_field'] != row['prepared_field']:
        if row["change"] == "":
            row["change"] = "resolved abbreviations"
            
def removechoices(row):
    if row['original_field'] != row['prepared_field']:
        if row["change"] == "":
            row["change"] = "removed choices"

df = pd.DataFrame(columns=["original_field", "prepared_field", "change"])
for column in gdb1.columns: 
    df.loc[len(df.index)] = [column, column.strip(), ""]
    
df.apply(strip_check, axis=1)
    
df['prepared_field'] = df['prepared_field'].str.replace('adj','adjuvant')
df['prepared_field'] = df['prepared_field'].str.replace('months OS','months overall survival')
df['prepared_field'] = df['prepared_field'].str.replace('PP','pseudo-progression')
df['prepared_field'] = df['prepared_field'].str.replace('PFS','progression-free survival')

df.apply(abbreviations, axis=1)
         
df['prepared_field'] = df['prepared_field'].str.replace('(1=yes 0=no)','', regex=False)
df.apply(removechoices, axis=1)
 
df.style.set_properties(**{'text-align': 'left'})
df.style.apply(show_difference, subset=['original_field', 'prepared_field'], axis=1)
# Out:
# <style type="text/css">
# #T_d718c_row3_col1, #T_d718c_row6_col1, #T_d718c_row10_col1, #T_d718c_row15_col1, #T_d718c_row18_col1, #T_d718c_row20_col1, #T_d718c_row21_col1, #T_d718c_row23_col1, #T_d718c_row24_col1, #T_d718c_row25_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_d718c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d718c_level0_col0" class="col_heading level0 col0" >original_field</th>
#       <th id="T_d718c_level0_col1" class="col_heading level0 col1" >prepared_field</th>
#       <th id="T_d718c_level0_col2" class="col_heading level0 col2" >change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d718c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d718c_row0_col0" class="data row0 col0" >ID Lab site</td>
#       <td id="T_d718c_row0_col1" class="data row0 col1" >ID Lab site</td>
#       <td id="T_d718c_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d718c_row1_col0" class="data row1 col0" >ID clinical site</td>
#       <td id="T_d718c_row1_col1" class="data row1 col1" >ID clinical site</td>
#       <td id="T_d718c_row1_col2" class="data row1 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d718c_row2_col0" class="data row2 col0" >DOB</td>
#       <td id="T_d718c_row2_col1" class="data row2 col1" >DOB</td>
#       <td id="T_d718c_row2_col2" class="data row2 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d718c_row3_col0" class="data row3 col0" >Age </td>
#       <td id="T_d718c_row3_col1" class="data row3 col1" >Age</td>
#       <td id="T_d718c_row3_col2" class="data row3 col2" >remove trailing spaces</td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d718c_row4_col0" class="data row4 col0" >Gender</td>
#       <td id="T_d718c_row4_col1" class="data row4 col1" >Gender</td>
#       <td id="T_d718c_row4_col2" class="data row4 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d718c_row5_col0" class="data row5 col0" >Pathology</td>
#       <td id="T_d718c_row5_col1" class="data row5 col1" >Pathology</td>
#       <td id="T_d718c_row5_col2" class="data row5 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d718c_row6_col0" class="data row6 col0" >Localization </td>
#       <td id="T_d718c_row6_col1" class="data row6 col1" >Localization</td>
#       <td id="T_d718c_row6_col2" class="data row6 col2" >remove trailing spaces</td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d718c_row7_col0" class="data row7 col0" >IDH1/2 status</td>
#       <td id="T_d718c_row7_col1" class="data row7 col1" >IDH1/2 status</td>
#       <td id="T_d718c_row7_col2" class="data row7 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d718c_row8_col0" class="data row8 col0" >MGMT status</td>
#       <td id="T_d718c_row8_col1" class="data row8 col1" >MGMT status</td>
#       <td id="T_d718c_row8_col2" class="data row8 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d718c_row9_col0" class="data row9 col0" >ECOG</td>
#       <td id="T_d718c_row9_col1" class="data row9 col1" >ECOG</td>
#       <td id="T_d718c_row9_col2" class="data row9 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d718c_row10_col0" class="data row10 col0" >Nature of initial resection </td>
#       <td id="T_d718c_row10_col1" class="data row10 col1" >Nature of initial resection</td>
#       <td id="T_d718c_row10_col2" class="data row10 col2" >remove trailing spaces</td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d718c_row11_col0" class="data row11 col0" >lymphocyte counts at V1 in G/L</td>
#       <td id="T_d718c_row11_col1" class="data row11 col1" >lymphocyte counts at V1 in G/L</td>
#       <td id="T_d718c_row11_col2" class="data row11 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d718c_row12_col0" class="data row12 col0" >cummulative dose preV1 steroid use in mg</td>
#       <td id="T_d718c_row12_col1" class="data row12 col1" >cummulative dose preV1 steroid use in mg</td>
#       <td id="T_d718c_row12_col2" class="data row12 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d718c_row13_col0" class="data row13 col0" >steroid use after V1</td>
#       <td id="T_d718c_row13_col1" class="data row13 col1" >steroid use after V1</td>
#       <td id="T_d718c_row13_col2" class="data row13 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d718c_row14_col0" class="data row14 col0" >cummulative steroid dose in mg</td>
#       <td id="T_d718c_row14_col1" class="data row14 col1" >cummulative steroid dose in mg</td>
#       <td id="T_d718c_row14_col2" class="data row14 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d718c_row15_col0" class="data row15 col0" > Cycles adj TMZ</td>
#       <td id="T_d718c_row15_col1" class="data row15 col1" >Cycles adjuvant TMZ</td>
#       <td id="T_d718c_row15_col2" class="data row15 col2" >remove trailing spaces</td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d718c_row16_col0" class="data row16 col0" >doses bevacizumab</td>
#       <td id="T_d718c_row16_col1" class="data row16 col1" >doses bevacizumab</td>
#       <td id="T_d718c_row16_col2" class="data row16 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d718c_row17_col0" class="data row17 col0" >Best response</td>
#       <td id="T_d718c_row17_col1" class="data row17 col1" >Best response</td>
#       <td id="T_d718c_row17_col2" class="data row17 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d718c_row18_col0" class="data row18 col0" >pseudo-progression (1=yes 0=no)</td>
#       <td id="T_d718c_row18_col1" class="data row18 col1" >pseudo-progression </td>
#       <td id="T_d718c_row18_col2" class="data row18 col2" >removed choices</td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d718c_row19_col0" class="data row19 col0" >œdema</td>
#       <td id="T_d718c_row19_col1" class="data row19 col1" >œdema</td>
#       <td id="T_d718c_row19_col2" class="data row19 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d718c_row20_col0" class="data row20 col0" >PP or œdema</td>
#       <td id="T_d718c_row20_col1" class="data row20 col1" >pseudo-progression or œdema</td>
#       <td id="T_d718c_row20_col2" class="data row20 col2" >resolved abbreviations</td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d718c_row21_col0" class="data row21 col0" >progression (1=yes 0=no)</td>
#       <td id="T_d718c_row21_col1" class="data row21 col1" >progression </td>
#       <td id="T_d718c_row21_col2" class="data row21 col2" >removed choices</td>
#     </tr>
#     <tr>
#       <th id="T_d718c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d718c_row22_col0" class="data row22 col0" >date of progression</td>
#       <td i

# %% [markdown]
# # Dataset 2 on Glioblastoma
# The second dataset is a provided excel file (dt_Bayraktar_ClinicalMetadata_mock_2022.07.21.xlsx) ## TODO add a link. It contains synthetic clinical data on patients with glioblastoma.

# %%
gdb2 = pd.read_excel("data/dt_Bayraktar_ClinicalMetadata_mock_2022.07.21.xlsx")
gdb2

# %%
gdb2.info()

# %%
def show_difference(row):
    highlight = 'background-color: yellow;'
    default = ''
    if row['original_field'] != row['prepared_field']:
        return [default, highlight]
    else:
        return [default, default]
    
def strip_check(row):
    if row['original_field'] != row['prepared_field']:
        row["change"] = "remove trailing spaces"
        
def abbreviations(row):
    if row['original_field'] != row['prepared_field']:
        if row["change"] == "":
            row["change"] = "resolved abbreviations"
            
def removechoices(row):
    if row['original_field'] != row['prepared_field']:
        if row["change"] == "":
            row["change"] = "removed choices"

df = pd.DataFrame(columns=["original_field", "prepared_field", "change"])
for column in gdb2.columns: 
    df.loc[len(df.index)] = [column, column.strip(), ""]
    
df.apply(strip_check, axis=1)
    
df['prepared_field'] = df['prepared_field'].str.replace('adj','adjuvant')
df['prepared_field'] = df['prepared_field'].str.replace('months OS','months overall survival')
df['prepared_field'] = df['prepared_field'].str.replace('PP','pseudo-progression')
df['prepared_field'] = df['prepared_field'].str.replace('PFS','progression-free survival')

df.apply(abbreviations, axis=1)
         
df['prepared_field'] = df['prepared_field'].str.replace('(1=yes 0=no)','', regex=False)
df.apply(removechoices, axis=1)
 
df.style.set_properties(**{'text-align': 'left'})
df.style.apply(show_difference, subset=['original_field', 'prepared_field'], axis=1)

# %% [markdown]
# In the next chapter the clarified field names will be used to identify terms in applicable controlled vocabularies ontologies to drive the linked data.

# %%
gdb2 = pd.read_excel("data/dt_Bayraktar_ClinicalMetadata_mock_2022.07.21.xlsx")
gdb2
# Out:
#    Sample ID  MPBTP (Sequencing Data)  # of blocks Sex  Age (optional)  \
# 0  Patient A                      NaN            5   M              54
# 1  Patient B                      NaN            4   F              82
# 2  Patient C                      NaN            4   F              41
#
#   Tumour Spatial Information  Pathology - pre-surgical  \
# 0         Right Temporal Lobe                     GBM
# 1         Right Temporal Lobe                     GBM
# 2          Right Frontal Lobe                     GBM
#
#                         Histopathological Assignment  \
# 0        Glioblastoma, IDH-wiltype (CNS WHO Grade 4)
# 1        Glioblastoma, IDH-wiltype (CNS WHO Grade 4)
# 2  Oligodendroglioma, IDH-mut and 1p/19q co-delet...
#
#             Histopathology - Microscopic Description  \
# 0  Cellular glial neoplasm with elongated nuclei ...
# 1  Pleomorphic astrocytes with numerous gemistocy...
# 2  Diffusely infiltrative glial neoplasm with mod...
#
#                                            Mutations  \
# 0       IDH-WT (IHC and Sequencing)\nATRX - Retained
# 1       IDH-WT (IHC and Sequencing)\nATRX - Retained
# 2  IDH1-mut R132H (IHC and Sequencing)\nATRX - Re...
#
#     Methylation Status (>10% = METHYLATED)  \
# 0  MGMT Promotor Methylation - 2% - ABSENT
# 1  MGMT Promotor Methylation - 5% - ABSENT
# 2                                No tested
#
#                                       Other Variants Covid test  \
# 0  EGFR Amplification;\nCDKN2A Deletion;\nPTEN De...   Negative
# 1                   CDKN2A Deletion; \nPTEN Deletion   Negative
# 2                   1p/19q Co-deletion; \nTP53 P152L   Negative
#
#              Other comments                                   Spatial Location
# 0  A1 has a duplicate block  Wasn’t able to get stealth location informatio...
# 1                         -  Anterior, Lateral, Posterior and Medial sample...
# 2        Sampled by Richard  Superior, Anterior, Deep and Inferior samples ...

# %%
gdb2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Sample ID                                 3 non-null      object
#  1   MPBTP (Sequencing Data)                   0 non-null      float64
#  2   # of blocks                               3 non-null      int64
#  3   Sex                                       3 non-null      object
#  4   Age (optional)                            3 non-null      int64
#  5   Tumour Spatial Information                3 non-null      object
#  6   Pathology - pre-surgical                  3 non-null      object
#  7   Histopathological Assignment              3 non-null      object
#  8   Histopathology - Microscopic Description  3 non-null      object
#  9   Mutations                                 3 non-null      object
#  10  Methylation Status (>10% = METHYLATED)    3 non-null      object
#  11  Other Variants                            3 non-null      object
#  12  Covid test                                3 non-null      object
#  13  Other comments                            3 non-null      object
#  14  Spatial Location                          3 non-null      object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 488.0+ bytes

# %%
def show_difference(row):
    highlight = 'background-color: yellow;'
    default = ''
    if row['original_field'] != row['prepared_field']:
        return [default, highlight]
    else:
        return [default, default]
    
def strip_check(row):
    if row['original_field'] != row['prepared_field']:
        row["change"] = "remove trailing spaces"
        
def abbreviations(row):
    if row['original_field'] != row['prepared_field']:
        if row["change"] == "":
            row["change"] = "resolved abbreviations"
            
def removechoices(row):
    if row['original_field'] != row['prepared_field']:
        if row["change"] == "":
            row["change"] = "removed conditionals"

df = pd.DataFrame(columns=["original_field", "prepared_field", "change"])
for column in gdb2.columns: 
    df.loc[len(df.index)] = [column, column.strip(), ""]
    
df.apply(strip_check, axis=1)
    
df['prepared_field'] = df['prepared_field'].str.replace('adj','adjuvant')
df['prepared_field'] = df['prepared_field'].str.replace('months OS','months overall survival')
df['prepared_field'] = df['prepared_field'].str.replace('PP','pseudo-progression')
df['prepared_field'] = df['prepared_field'].str.replace('PFS','progression-free survival')

df.apply(abbreviations, axis=1)
         
df['prepared_field'] = df['prepared_field'].str.replace('(optional)','', regex=False)
df.apply(removechoices, axis=1)
 
df.style.set_properties(**{'text-align': 'left'})
df.style.apply(show_difference, subset=['original_field', 'prepared_field'], axis=1)
# Out:
# <style type="text/css">
# #T_4c26c_row4_col1, #T_4c26c_row5_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_4c26c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c26c_level0_col0" class="col_heading level0 col0" >original_field</th>
#       <th id="T_4c26c_level0_col1" class="col_heading level0 col1" >prepared_field</th>
#       <th id="T_4c26c_level0_col2" class="col_heading level0 col2" >change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c26c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c26c_row0_col0" class="data row0 col0" >Sample ID</td>
#       <td id="T_4c26c_row0_col1" class="data row0 col1" >Sample ID</td>
#       <td id="T_4c26c_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4c26c_row1_col0" class="data row1 col0" >MPBTP (Sequencing Data)</td>
#       <td id="T_4c26c_row1_col1" class="data row1 col1" >MPBTP (Sequencing Data)</td>
#       <td id="T_4c26c_row1_col2" class="data row1 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4c26c_row2_col0" class="data row2 col0" ># of blocks</td>
#       <td id="T_4c26c_row2_col1" class="data row2 col1" ># of blocks</td>
#       <td id="T_4c26c_row2_col2" class="data row2 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4c26c_row3_col0" class="data row3 col0" >Sex</td>
#       <td id="T_4c26c_row3_col1" class="data row3 col1" >Sex</td>
#       <td id="T_4c26c_row3_col2" class="data row3 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4c26c_row4_col0" class="data row4 col0" >Age (optional)</td>
#       <td id="T_4c26c_row4_col1" class="data row4 col1" >Age </td>
#       <td id="T_4c26c_row4_col2" class="data row4 col2" >removed conditionals</td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4c26c_row5_col0" class="data row5 col0" >Tumour Spatial Information </td>
#       <td id="T_4c26c_row5_col1" class="data row5 col1" >Tumour Spatial Information</td>
#       <td id="T_4c26c_row5_col2" class="data row5 col2" >remove trailing spaces</td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4c26c_row6_col0" class="data row6 col0" >Pathology - pre-surgical</td>
#       <td id="T_4c26c_row6_col1" class="data row6 col1" >Pathology - pre-surgical</td>
#       <td id="T_4c26c_row6_col2" class="data row6 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4c26c_row7_col0" class="data row7 col0" >Histopathological Assignment</td>
#       <td id="T_4c26c_row7_col1" class="data row7 col1" >Histopathological Assignment</td>
#       <td id="T_4c26c_row7_col2" class="data row7 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4c26c_row8_col0" class="data row8 col0" >Histopathology - Microscopic Description</td>
#       <td id="T_4c26c_row8_col1" class="data row8 col1" >Histopathology - Microscopic Description</td>
#       <td id="T_4c26c_row8_col2" class="data row8 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4c26c_row9_col0" class="data row9 col0" >Mutations</td>
#       <td id="T_4c26c_row9_col1" class="data row9 col1" >Mutations</td>
#       <td id="T_4c26c_row9_col2" class="data row9 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4c26c_row10_col0" class="data row10 col0" >Methylation Status (>10% = METHYLATED)</td>
#       <td id="T_4c26c_row10_col1" class="data row10 col1" >Methylation Status (>10% = METHYLATED)</td>
#       <td id="T_4c26c_row10_col2" class="data row10 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4c26c_row11_col0" class="data row11 col0" >Other Variants</td>
#       <td id="T_4c26c_row11_col1" class="data row11 col1" >Other Variants</td>
#       <td id="T_4c26c_row11_col2" class="data row11 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4c26c_row12_col0" class="data row12 col0" >Covid test</td>
#       <td id="T_4c26c_row12_col1" class="data row12 col1" >Covid test</td>
#       <td id="T_4c26c_row12_col2" class="data row12 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4c26c_row13_col0" class="data row13 col0" >Other comments</td>
#       <td id="T_4c26c_row13_col1" class="data row13 col1" >Other comments</td>
#       <td id="T_4c26c_row13_col2" class="data row13 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c26c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4c26c_row14_col0" class="data row14 col0" >Spatial Location</td>
#       <td id="T_4c26c_row14_col1" class="data row14 col1" >Spatial Location</td>
#       <td id="T_4c26c_row14_col2" class="data row14 col2" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# In the next chapter the clarified field names will be used to identify terms in applicable controlled vocabularies ontologies to drive the linked data.
